# %%
# %%time
from IPython import display

# !pip install ultralytics opencv-python numpy torch torchvision torchaudio
display.clear_output()
# Out:
# CPU times: user 25.6 ms, sys: 2.24 ms, total: 27.8 ms
# Wall time: 3.32 s

# %%
from ultralytics import YOLO
model_detect = YOLO("yolo11n.pt")
model_seg = YOLO("yolo11n-seg.pt")
model_pose = YOLO("yolo11n-pose.pt")
#model_custom = YOLO("path/to/best.pt")

# %%
model_detect= model_detect.track("https://youtu.be/LNwODJXcvt4", show=True,save=True)
#results_custom = model_custom.track("https://youtu.be/LNwODJXcvt4", show=True)
# Out:
# 1/1: https://youtu.be/LNwODJXcvt4... Success ✅ (10842 frames of shape 1920x1080 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs

# %%
# !pip install pytube
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install yt-dlp
display.clear_output()

# %%
import os

yt_url = "https://youtube.com/shorts/MG_znWM5ETk"

# Download the best quality MP4 format
os.system(f'yt-dlp -f "best[ext=mp4]" {yt_url} -o youtube_video.mp4')

print("Downloaded video as youtube_video.mp4")
# Out:
# Downloaded video as youtube_video.mp4

# %%
from pytube import YouTube
from ultralytics import YOLO


# Run tracking on the downloaded video
results = model_pose.track("/content/youtube_video.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/680) /content/youtube_video.mp4: 640x384 (no detections), 574.9ms
# video 1/1 (frame 2/680) /content/youtube_video.mp4: 640x384 (no detections), 19.5ms
# video 1/1 (frame 3/680) /content/youtube_video.mp4: 640x384 (no detections), 24.5ms
# video 1/1 (frame 4/680) /content/youtube_video.mp4: 640x384 (no detections), 17.3ms
# ...

# %%
from google.colab import files

files.download("/content/runs/segment/track/youtube_video.avi")  # Adjust path if needed

# %%
results_seg = model_seg.track("/content/youtube_video.mp4", show=True,save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/680) /content/youtube_video.mp4: 640x384 1 dog, 1 sports ball, 1 apple, 542.4ms
# video 1/1 (frame 2/680) /content/youtube_video.mp4: 640x384 1 dog, 1 sports ball, 1 apple, 136.3ms
# video 1/1 (frame 3/680) /content/youtube_video.mp4: 640x384 1 dog, 1 sports ball, 1 apple, 32.3ms
# ...
